# %%
import tensorflow as tf
import numpy as np
import pandas as pd

from tensorflow import feature_column
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split

# %%
os.chdir('C:/Users/Clint/PycharmProjects/ML-MATLAB/python')
from datasets import StykuDataSet_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-411cf86dddd0> in <module>
# ----> 1 os.chdir('C:/Users/Clint/PycharmProjects/ML-MATLAB/python')
#       2 from datasets import StykuDataSet_1
#
# NameError: name 'os' is not defined
