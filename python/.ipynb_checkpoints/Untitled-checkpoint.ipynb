# %%
import tensorflow as tf
import numpy as np
import pandas as pd

from tensorflow import feature_column
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split

# %%
import sys
sys.executable 
sys.path
# Out:
# ['C:\\Users\\Clint',
#  'C:\\Users\\Clint\\Anaconda3\\envs\\ml\\python37.zip',
#  'C:\\Users\\Clint\\Anaconda3\\envs\\ml\\DLLs',
#  'C:\\Users\\Clint\\Anaconda3\\envs\\ml\\lib',
#  'C:\\Users\\Clint\\Anaconda3\\envs\\ml',
#  '',
#  'C:\\Users\\Clint\\Anaconda3\\envs\\ml\\lib\\site-packages',
#  'C:\\Users\\Clint\\Anaconda3\\envs\\ml\\lib\\site-packages\\win32',
#  'C:\\Users\\Clint\\Anaconda3\\envs\\ml\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\Clint\\Anaconda3\\envs\\ml\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\Clint\\Anaconda3\\envs\\ml\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\Clint\\.ipython',
#  'C:\\Users']

# %%
from datasets import NhanesDataSet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-e661ad4c6e79> in <module>
# ----> 1 from datasets import NhanesDataSet
#
# ModuleNotFoundError: No module named 'datasets'
